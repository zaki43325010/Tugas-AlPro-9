# %% [markdown]
# <a href="https://colab.research.google.com/github/zaki43325010/Tugas-AlPro-9/blob/main/laporan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def score_akhir(total_benar, jumlah_soal):
  print(f"\nTotal benar: {total_benar}")
  print(f"Jumlah soal: {jumlah_soal}")
  nilai=(total_benar/jumlah_soal)*100
  print(f"Nilai: {nilai}")
