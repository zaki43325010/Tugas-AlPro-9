# %% [markdown]
# <a href="https://colab.research.google.com/github/zaki43325010/Tugas-AlPro-9/blob/main/modulku.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def halo(nama):
  print(f"Halo,{nama}! Selamat belajar phyton di Polines.")
